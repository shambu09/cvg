# %% [markdown]
# ![image.png](attachment:db589817-15fa-4b1b-b979-9d2f8eca05a7.png)

# %%
if __name__ == '__main__':
    n = int(input())
    for x in range(n):
        print(x+1, end='')
# Out:
#  8
# 12345678
