# %% [markdown]
# ![image.png](attachment:35e883d2-2a01-4df0-963d-3d2211639834.png)

# %%
def swap_case(s):
    new = ""
    for alpha in s:
        if alpha.isupper():
            temp = alpha.lower()
        else:
            temp = alpha.upper()
        new += temp
    return new

if __name__ == '__main__':
    s = input()
    result = swap_case(s)
    print(result)
