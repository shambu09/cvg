# %% [markdown]
# ![image.png](attachment:28d145ea-4248-4cee-bec6-5aa0355bf4ce.png)

# %% [markdown]
# ![image.png](attachment:a19b273a-a1dc-49c4-a749-d6bf183f4469.png)

# %%
def mutate_string(string, position, character):
    new = list(string)
    new[position] = character
    new = "".join(new)
    return new 

if __name__ == '__main__':
    s = input()
    i, c = input().split()
    s_new = mutate_string(s, int(i), c)
    print(s_new)
