# %% [markdown]
# ![image.png](attachment:a11f63a9-2252-4f94-a1e9-c893e273ee4a.png)

# %%
def split_and_join(line):
    # write your code here
    new = line.replace(" ", "-")
    return new

if __name__ == '__main__':
    line = input()
    result = split_and_join(line)
    print(result)
# Out:
#  this is a string
# this-is-a-string
