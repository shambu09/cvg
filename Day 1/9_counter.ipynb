# %% [markdown]
# ![image.png](attachment:d7df36e6-570d-43c9-85dc-ec2ff427f01d.png)

# %% [markdown]
# ![image.png](attachment:c050afc7-e304-4b22-8530-044874c6c28e.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
from collections import Counter

shoes = int(input())
size_list = list(map(int, input().split(" ")))
cust_num = int(input())
queue = [list(map(int, input().split(" "))) for x in range(cust_num)]

inventory = Counter(size_list)
money = 0

for x in queue:
    if inventory[x[0]] != 0:
        money += x[1]
        inventory[x[0]] -= 1

print(money)
